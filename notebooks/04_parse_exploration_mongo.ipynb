# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from pandas import DataFrame
from bson import ObjectId
from pandas import json_normalize
# from pandas.io.json import json_normalize
print ("pymongo version:", pymongo.version)

pd.set_option('display.max_columns', 1010)
pd.set_option('display.max_rows', 1010)
# Out:
# pymongo version: 3.10.1

# %% [markdown]
# ### Check status mongodb
# * sudo service mongodb status
# * sudo service mongodb start

# %%
mongo_client = MongoClient('localhost', 27017)
host_info = mongo_client['HOST']
print ("\nhost:", host_info)
# Out:
# host: Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'HOST')

# %% [markdown]
# ### List databases

# %%
print(mongo_client.list_database_names())
# Out:
# ['admin', 'legalthings', 'local']

# %%
legalthings_db = mongo_client["legalthings"]

# %% [markdown]
# ### Show collections in database

# %%
all_collections = legalthings_db.list_collection_names ()

# %% [markdown]
# ### Explore query possibilities

# %% [markdown]
# #### One '_id' can have multiple persons, search on objectid

# %%
legalthings_db['processes_18'].find({})[0]
# Out:
# {'_id': ObjectId('5e0f3964526253513f8b4567'),
#  'title': 'BV Oprichten',
#  'name': 'Jan George | n.t.b',
#  'scenario': {'name': 'BV Oprichten (funnel)',
#   'image': None,
#   'description': None,
#   'alias': [{'key': 'spaar-bv', 'value': 'Spaar BV Oprichten'},
#    {'key': 'normal-bv', 'value': 'BV Oprichten'},
#    {'key': 'holding', 'value': 'Holding Oprichten'},
#    {'key': 'inbreng', 'value': 'BV Oprichten met Inbreng'},
#    {'key': 'fusie', 'value': 'Aandelen-/Bedrijfsfusie'},
#    {'key': 'zorg', 'value': 'Zorg BV Oprichten'},
#    {'key': 'stichting', 'value': 'Stichting Oprichten'}],
#   'title': 'BV Oprichten',
#   'actors': [{'title': 'Cliënt',
#     'requirement': None,
#     'id': None,
#     'organization': None,
#     'name': None,
#     'absent': False,
#     'key': 'user'},
#    {'title': 'Notaris',
#     'requirement': None,
#     'id': {'<ref>': 'global.config.legalflow.workflows.general.notary.id'},
#     'organization': {'id': None,
#      'name': None,
#      'type': None,
#      '<ref>': 'global.config.legalflow.workflows.general.notary.organization'},
#     'absent': False,
#     'key': 'notary'},
#    {'title': {'<ref>': 'global.config.legalflow.workflows.general.company.name'},
#     'requirement': None,
#     'id': None,
#     'organization': 'primary',
#     'name': None,
#     'absent': False,
#     'key': 'primary'}],
#   'actions': [{'definition': 'update-process',
#     'title': 'Initialize process',
#     'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'name': {'<ref>': 'data.name'},
#       'portal': {'<ref>': 'global.config.legalflow.workflows.general.portal'},
#       'actors': [{'key': 'user',
#         'title': 'User',
#         'id': {'<if>': {'condition': {'<tpl>': '{{ data.user }}'},
#           'then': {'<ref>': 'data.user'},
#           'else': {'<ref>': 'global.session.user.id'}}},
#         'organization': {'<ref>': 'data.organization'}}],
#       'alias_key': {'<ref>': 'data.alias.key'},
#       'locale': {'<ref>': 'data.locale'}}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'set_incorporation_type',
#       'update': {'select': '$', 'patch': True, 'data': None, 'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'initialize_process'},
#    {'definition': 'update-process',
#     'title': 'Set incorporation type',
#     'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'incorporation_type': {'<switch>': 'data.alias.key',
#        'normal-bv': 'BV',
#        'holding': 'Holding',
#        'spaar-bv': 'Spaar BV',
#        'stichting': 'Stichting',
#        'emz-bv': 'BV',
#        'omzetting': 'BV'}}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'add_name_to_activecampaign',
#       'update': {'select': 'private_data',
#        'patch': True,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'set_incorporation_type'},
#    {'trigger': {'type': 'http',
#      'url': 'https://firm24.api-us1.com/admin/api.php',
#      'method': 'POST',
#      'query': {'api_output': 'json',
#       'api_key': {'<ref>': 'global.config.legalflow.workflows.general.active_campaign.api_key'},
#       'api_action': 'contact_sync'},
#      'headers': {'Content-Type': 'application/x-www-form-urlencoded'},
#      'auth': None,
#      'data': {'email': {'<ref>': 'actors.user.email'},
#       'first_name': {'<ref>': 'actors.user.first_name'},
#       'last_name': {'<ref>': 'actors.user.last_name'},
#       'field[%NAME_COMPANY%,0]': {'<ref>': 'data.name'},
#       'phone': {'<ref>': 'actors.user.phone'},
#       'tags': {'<merge>': [{'<tpl>': '{{ portal }},Nieuwe BV Funnel,'},
#         {'<switch>': 'data.locale', 'nl': '', 'en': 'nl-EN'},
#         {'<tpl>': ','},
#         {'<switch>': {'on': {'<ref>': 'data.tag'},
#           'options': {'accountant': 'start pro'},
#           'default': {'<switch>': 'data.alias.key',
#            'normal-bv': 'BV procedure has started',
#            'holding': 'holding procedure has started',
#            'spaar-bv': 'spaar-bv procedure has started',
#            'inbreng': 'inbreng procedure has started',
#            'fusie': 'fusie procedure has started',
#            'zorg': 'zorg procedure has started',
#            'stichting': 'Stichting procedure has started',
#            'emz-bv': 'BV procedure has started',
#            'omzetting': 'BV procedure has started'}}}]}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#         'options': {'stichting': 'create_stichting_document_step',
#          'inbreng': 'create_inbreng_document_step',
#          'omzetting': 'create_omzetten_document_step'},
#         'default': 'create_document_step'}},
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#         'options': {'stichting': 'create_stichting_document_step',
#          'inbreng': 'create_inbreng_document_step',
#          'omzetting': 'create_omzetten_document_step'},
#         'default': 'create_document_step'}},
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'add_name_to_activecampaign'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.legaldocx.url }}/documents'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'template': 'voorbeeld_akte_oprichting_v2',
#       'organization_id': {'<ref>': 'actors.user.organization.id'},
#       'name': {'<ref>': 'data.name'},
#       'values': {'<merge>': [{'ah': {'<ifset>': 'data.values',
#           '<ref>': 'data.values.ah'}},
#         {'data': {'<merge>': [{'<ifset>': 'data.values',
#             '<ref>': 'data.values.data'},
#            {'naam_onderneming': {'<ref>': 'data.name'},
#             'bv_type': {'<switch>': 'data.alias.key',
#              'normal-bv': 'Besloten Vennootschap',
#              'holding': 'Holding',
#              'spaar-bv': 'Spaar BV',
#              'stichting': 'Stichting',
#              'emz-bv': 'Besloten Vennootschap',
#              'inbreng': 'Besloten Vennootschap',
#              'omzetting': 'Besloten Vennootschap'},
#             'conceptakte': {'<switch>': 'data.locale',
#              'nl': {'<switch>': 'data.alias.key',
#               'spaar-bv': 'concept_nl.pdf',
#               'normal-bv': 'concept_nl.pdf',
#               'holding': 'concept_nl.pdf',
#               'stichting': 'concept_stichting.pdf',
#               'omzetting': 'concept_nl.pdf'},
#              'en': {'<switch>': 'data.alias.key',
#               'spaar-bv': 'concept_en.pdf',
#               'normal-bv': 'concept_en.pdf',
#               'holding': 'concept_en.pdf',
#               'stichting': 'concept_stichting.pdf'}}}]},
#          'kvk': {'<merge>': [{'<ifset>': 'data.values',
#             '<ref>': 'data.values.kvk'},
#            {'type_toelichting': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#               'options': {'holding': {'<switch>': 'data.locale',
#                 'nl': 'Holding activiteiten',
#                 'en': 'Holding activities'}},
#               'default': ''}},
#             'fulltime_werknemers': '',
#             'parttime_werknemers': '',
#             'telefoonnummer': '',
#             'website': ''}]}},
#         {'products': {'package': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv'}},
#              {'name': 'Oprichting',
#               'count': {'<switch>': 'data.locale',
#                'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                  'options': {'normal-bv': 1, 'holding': 1},
#                  'default': 0}},
#                'en': 0}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_en'}},
#              {'name': 'Incorporation',
#               'count': {'<switch>': 'data.locale',
#                'nl': 0,
#                'en': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                  'options': {'normal-bv': 1, 'holding': 1},
#                  'default': 0}}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_spaarbv'}},
#              {'name': 'Oprichting',
#               'count': {'<switch>': 'data.locale',
#                'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                  'options': {'spaar-bv': 1},
#                  'default': 0}}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_eenmanszaak_omzetten'}},
#              {'name': 'Oprichting',
#               'count': {'<switch>': 'data.locale',
#                'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                  'options': {'emz-bv': 1},
#                  'default': 0}}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga'}},
#              {'name': 'DGA Salaris', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_enkele_aandeelhouder'}},
#              {'name': 'Contracten voor één aandeelhouder', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_meerdere_aandeelhouders'}},
#              {'name': 'Contracten voor meerdere aandeelhouder', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat'}},
#              {'name': 'Wettelijke bijdrage Kwaliteitsfonds Notariaat',
#               'count': {'<switch>': 'data.locale', 'nl': 1, 'en': 0}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat_en'}},
#              {'name': 'Legal contribution to the Quality Fund for the Dutch Notarial Profession',
#               'count': {'<switch>': 'data.locale', 'nl': 0, 'en': 1}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_holding'}},
#              {'name': 'Holding', 'count': 0}]},
#            {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_korting'}},
#            {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga_korting'}}],
#           'addons': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_boekhouding'}},
#              {'name': 'Help mij met mijn boekhouding',
#               'description': 'Voorkomen is beter dan genezen. In samenwerking met <strong>offerte.nl</strong> word je gebeld door boekhouder(s) uit jouw omgeving om een passende <strong>vrijblijvende offerte</strong> te ontvangen. Voorkom boetes en start direct met een strakke administratie!',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_sneloprichten'}},
#              {'name': 'Snel oprichten',
#               'description': 'BV of holding wordt binnen 3 á 5 werkdagen in plaats van onze standaard oprichtingsproces van 7 werkdagen voor je opgericht.',
#               'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                 'options': {'firm24_addon_sneloprichten': 1},
#                 'default': 0}}},
#              {'count': {'<if>': {'condition': {'<tpl>': '{{ data.values }}'},
#                 'then': {'<ref>': 'data.values',
#                  '<jmespath>': 'products.addons[?id==`firm24_addon_sneloprichten`].count | [0]'},
#                 'else': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                   'options': {'firm24_addon_sneloprichten': 1},
#                   'default': 0}}}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_sneloprichten_en'}},
#              {'name': 'Priority incorporation',
#               'description': 'Your company will be incorporated within 3 to 5 business days instead of the standard 7 business days.',
#               'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                 'options': {'firm24_addon_sneloprichten_en': 1},
#                 'default': 0}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_spoedoprichting_en'}},
#              {'name': 'Urgent incorporation',
#               'description': 'Already done more than 4200 urgent incorporations. Your company will be incorporated within 48 hours. Do you want to be able to act tommorow from your incorporation? You need a notary immediately for an urgent incorporation of your company. With our unique 48-hour service we can incorporate your company and register it with the Chamber of Commerce within 48 hours.',
#               'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                 'options': {'firm24_addon_spoedoprichting_en': 1},
#                 'default': 0}}}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_spoedoprichting'}},
#              {'name': 'Spoedoprichting',
#               'description': 'Al meer dan 4200 spoedoprichtingen gedaan. BV of holding wordt binnen 48 uur voor je opgericht. Wil je morgen kunnen handelen vanuit de BV? Je hebt direct een notaris nodig voor een spoedoprichting BV of stichting. Met onze unieke 48-uur service, kunnen wij een BV binnen 48 uur oprichten en inschrijven bij de Kamer van Koophandel.',
#               'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                 'options': {'firm24_addon_spoedoprichting': 1},
#                 'default': 0}}},
#              {'count': {'<if>': {'condition': {'<tpl>': '{{ data.values }}'},
#                 'then': {'<ref>': 'data.values',
#                  '<jmespath>': 'products.addons[?id==`firm24_addon_spoedoprichting`].count | [0]'},
#                 'else': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#                   'options': {'firm24_addon_spoedoprichting': 1},
#                   'default': 0}}}}}]}],
#           'extras': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders'}},
#              {'name': 'Extra aandeelhouders', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders_en'}},
#              {'name': 'Extra shareholders', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap'}},
#              {'name': 'Aandeelhouder is vennootschap', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap_en'}},
#              {'name': 'Shareholder is an existing Legal Entity', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_niet_nl'}},
#              {'name': 'Aandeelhouder spreekt geen Nederlands', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_buitenlandse_vennootschap'}},
#              {'name': 'Aandeelhouder is een buitenlandse vennootschap',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn'}},
#              {'name': 'Aandeelhouder is niet woonachtig in Nederland',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn_en'}},
#              {'name': 'Shareholder does not live in the Netherlands',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_large_share_capital'}},
#              {'name': 'Gebruik derdengeldenrekening notaris i.v.m. hoog aandelenkapitaal.',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_large_share_capital_en'}},
#              {'name': 'Use of third-party account of notary due to higher capital of shares.',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_foreign_ah'}},
#              {'name': 'Aandeelhouder woont niet in Nederland', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr'}},
#              {'name': 'Additioneel onderzoek o.g.v. Wwft', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr_en'}},
#              {'name': 'Additional research due to Wwft', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_advocaat_statuten'}},
#              {'name': 'Advocaat statuten', 'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_medische_statuten_holding'}},
#              {'name': 'Statuten voor participeren in een medische maatschap',
#               'count': 0}]},
#            {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_wtzi_statuten'}},
#              {'name': 'WTZI-statuten', 'count': 0}]}]}},
#         {'portal': {'<ref>': 'global.config.legalflow.workflows.general.portal'}}]}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'fill_document_user_step',
#       'update': {'select': 'private_data.legaldocx_document',
#        'patch': False,
#        'data': None,
#        'jmespath': '{id: id}'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'create_document_step'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.legaldocx.url }}/documents'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'template': 'voorbeeld_akte_oprichting_v2',
#       'organization_id': {'<ref>': 'actors.user.organization.id'},
#       'name': {'<ref>': 'data.name'},
#       'values': {'data': {'naam_onderneming': {'<ref>': 'data.name'},
#         'bv_type': {'<switch>': 'data.alias.key',
#          'normal-bv': 'Besloten Vennootschap',
#          'holding': 'Holding',
#          'spaar-bv': 'Spaar BV',
#          'stichting': 'Stichting',
#          'emz-bv': 'Besloten Vennootschap',
#          'inbreng': 'Besloten Vennootschap',
#          'omzetting': 'Besloten Vennootschap'},
#         'conceptakte': {'<switch>': 'data.locale',
#          'nl': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_nl.pdf',
#           'normal-bv': 'concept_nl.pdf',
#           'holding': 'concept_nl.pdf',
#           'stichting': 'concept_stichting.pdf',
#           'omzetting': 'concept_nl.pdf'},
#          'en': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_en.pdf',
#           'normal-bv': 'concept_en.pdf',
#           'holding': 'concept_en.pdf',
#           'stichting': 'concept_stichting.pdf'}}},
#        'products': {'package': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_inbreng'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'stichting': 0},
#                'default': 1}},
#              'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_en'}},
#            {'name': 'Incorporation',
#             'count': {'<switch>': 'data.locale',
#              'nl': 0,
#              'en': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'stichting': 1},
#                'default': 1}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_spaarbv'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'spaar-bv': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_eenmanszaak_omzetten'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'emz-bv': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga'}},
#            {'name': 'DGA Salaris', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_enkele_aandeelhouder'}},
#            {'name': 'Contracten voor één aandeelhouder', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_meerdere_aandeelhouders'}},
#            {'name': 'Contracten voor meerdere aandeelhouder', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat'}},
#            {'name': 'Wettelijke bijdrage Kwaliteitsfonds Notariaat',
#             'count': {'<switch>': 'data.locale', 'nl': 1, 'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat_en'}},
#            {'name': 'Legal contribution to the Quality Fund for the Dutch Notarial Profession',
#             'count': {'<switch>': 'data.locale', 'nl': 0, 'en': 1}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_holding'}},
#            {'name': 'Holding', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_notariele_inbrengakte'}},
#            {'name': 'Notariële inbrengakte (onderneming)',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'inbreng': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_notariele_inbrengakte_onroerende_zaak'}},
#            {'name': 'Notariële inbrengakte (onroerende zaak)', 'count': 0}]},
#          {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_korting'}},
#          {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga_korting'}}],
#         'addons': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_boekhouding'}},
#            {'name': 'Help mij met mijn boekhouding',
#             'description': 'Voorkomen is beter dan genezen. In samenwerking met <strong>offerte.nl</strong> word je gebeld door boekhouder(s) uit jouw omgeving om een passende <strong>vrijblijvende offerte</strong> te ontvangen. Voorkom boetes en start direct met een strakke administratie!',
#             'count': 0}]}],
#         'extras': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders'}},
#            {'name': 'Extra aandeelhouders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders_en'}},
#            {'name': 'Extra shareholders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap'}},
#            {'name': 'Aandeelhouder is vennootschap', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap_en'}},
#            {'name': 'Shareholder is an existing Legal Entity', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_niet_nl'}},
#            {'name': 'Aandeelhouder spreekt geen Nederlands', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_buitenlandse_vennootschap'}},
#            {'name': 'Aandeelhouder is een buitenlandse vennootschap',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn'}},
#            {'name': 'Aandeelhouder is niet woonachtig in Nederland',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn_en'}},
#            {'name': 'Shareholder does not live in the Netherlands',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_foreign_ah'}},
#            {'name': 'Aandeelhouder woont niet in Nederland', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_inschrijfkosten_kadaster'}},
#            {'name': 'Inschrijfkosten kadaster', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr'}},
#            {'name': 'Additioneel onderzoek o.g.v. Wwft', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr_en'}},
#            {'name': 'Additional research due to Wwft', 'count': 0}]}]},
#        'portal': {'<ref>': 'global.config.legalflow.workflows.general.portal'}}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'fill_document_user_step',
#       'update': {'select': 'private_data.legaldocx_document',
#        'patch': False,
#        'data': None,
#        'jmespath': '{id: id}'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'create_inbreng_document_step'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.legaldocx.url }}/documents'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'template': 'voorbeeld_akte_oprichting_v2',
#       'organization_id': {'<ref>': 'actors.user.organization.id'},
#       'name': {'<ref>': 'data.name'},
#       'values': {'data': {'naam_onderneming': {'<ref>': 'data.name'},
#         'bv_type': {'<switch>': 'data.alias.key',
#          'normal-bv': 'Besloten Vennootschap',
#          'holding': 'Holding',
#          'spaar-bv': 'Spaar BV',
#          'stichting': 'Stichting',
#          'emz-bv': 'Besloten Vennootschap',
#          'inbreng': 'Besloten Vennootschap',
#          'omzetting': 'Besloten Vennootschap'},
#         'conceptakte': {'<switch>': 'data.locale',
#          'nl': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_nl.pdf',
#           'normal-bv': 'concept_nl.pdf',
#           'holding': 'concept_nl.pdf',
#           'stichting': 'concept_stichting.pdf',
#           'omzetting': 'concept_nl.pdf'},
#          'en': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_en.pdf',
#           'normal-bv': 'concept_en.pdf',
#           'holding': 'concept_en.pdf',
#           'stichting': 'concept_stichting.pdf'}}},
#        'products': {'package': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'stichting': 0},
#                'default': 1}},
#              'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_en'}},
#            {'name': 'Incorporation',
#             'count': {'<switch>': 'data.locale',
#              'nl': 0,
#              'en': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'normal-bv': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_spaarbv'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'spaar-bv': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_eenmanszaak_omzetten'}},
#            {'name': 'Oprichting',
#             'count': {'<switch>': 'data.locale',
#              'nl': {'<switch>': {'on': {'<ref>': 'data.alias.key'},
#                'options': {'emz-bv': 1},
#                'default': 0}}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga'}},
#            {'name': 'DGA Salaris', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_enkele_aandeelhouder'}},
#            {'name': 'Contracten voor één aandeelhouder', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_meerdere_aandeelhouders'}},
#            {'name': 'Contracten voor meerdere aandeelhouder', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat'}},
#            {'name': 'Wettelijke bijdrage Kwaliteitsfonds Notariaat',
#             'count': {'<switch>': 'data.locale', 'nl': 1, 'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat_en'}},
#            {'name': 'Legal contribution to the Quality Fund for the Dutch Notarial Profession',
#             'count': {'<switch>': 'data.locale', 'nl': 0, 'en': 1}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_holding'}},
#            {'name': 'Holding', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_onderneming_omzetten'}},
#            {'name': 'Omzetten onderneming', 'count': 0}]},
#          {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bv_korting'}},
#          {'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_dga_korting'}}],
#         'addons': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_boekhouding'}},
#            {'name': 'Help mij met mijn boekhouding',
#             'description': 'Voorkomen is beter dan genezen. In samenwerking met <strong>offerte.nl</strong> word je gebeld door boekhouder(s) uit jouw omgeving om een passende <strong>vrijblijvende offerte</strong> te ontvangen. Voorkom boetes en start direct met een strakke administratie!',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_sneloprichten'}},
#            {'name': 'Snel oprichten',
#             'description': 'BV of holding wordt binnen 3 á 5 werkdagen in plaats van onze standaard oprichtingsproces van 7 werkdagen voor je opgericht.',
#             'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#               'options': {'firm24_addon_sneloprichten': 1,
#                'firm24_addon_spoedoprichting': 0},
#               'default': 0}}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_spoedoprichting'}},
#            {'name': 'Spoedoprichting',
#             'description': 'Al meer dan 4200 spoedoprichtingen gedaan. BV of holding wordt binnen 48 uur voor je opgericht. Wil je morgen kunnen handelen vanuit de BV? Je hebt direct een notaris nodig voor een spoedoprichting BV of stichting. Met onze unieke 48-uur service, kunnen wij een BV binnen 48 uur oprichten en inschrijven bij de Kamer van Koophandel.',
#             'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#               'options': {'firm24_addon_sneloprichten': 0,
#                'firm24_addon_spoedoprichting': 1},
#               'default': 0}}}]}],
#         'extras': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders'}},
#            {'name': 'Extra aandeelhouders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders_en'}},
#            {'name': 'Extra shareholders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap'}},
#            {'name': 'Aandeelhouder is vennootschap', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap_en'}},
#            {'name': 'Shareholder is an existing Legal Entity', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_niet_nl'}},
#            {'name': 'Aandeelhouder spreekt geen Nederlands', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_buitenlandse_vennootschap'}},
#            {'name': 'Aandeelhouder is een buitenlandse vennootschap',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn'}},
#            {'name': 'Aandeelhouder is niet woonachtig in Nederland',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn_en'}},
#            {'name': 'Shareholder does not live in the Netherlands',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_large_share_capital'}},
#            {'name': 'Gebruik derdengeldenrekening notaris i.v.m. hoog aandelenkapitaal.',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_large_share_capital_en'}},
#            {'name': 'Use of third-party account of notary due to higher capital of shares.',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_foreign_ah'}},
#            {'name': 'Aandeelhouder woont niet in Nederland', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr'}},
#            {'name': 'Additioneel onderzoek o.g.v. Wwft', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr_en'}},
#            {'name': 'Additional research due to Wwft', 'count': 0}]}]},
#        'portal': {'<ref>': 'global.config.legalflow.workflows.general.portal'}}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'fill_document_user_step',
#       'update': {'select': 'private_data.legaldocx_document',
#        'patch': False,
#        'data': None,
#        'jmespath': '{id: id}'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'create_omzetten_document_step'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.legaldocx.url }}/documents'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'template': '968605c8-7721-4eb5-afca-d7380e4f03bc',
#       'organization_id': {'<ref>': 'actors.user.organization.id'},
#       'name': {'<ref>': 'data.name'},
#       'values': {'data': {'naam_onderneming': {'<ref>': 'data.name'},
#         'bv_type': {'<switch>': 'data.alias.key',
#          'normal-bv': 'Besloten Vennootschap',
#          'holding': 'Holding',
#          'spaar-bv': 'Spaar BV',
#          'stichting': 'Stichting'},
#         'conceptakte': {'<switch>': 'data.locale',
#          'nl': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_nl.pdf',
#           'normal-bv': 'concept_nl.pdf',
#           'holding': 'concept_nl.pdf',
#           'stichting': 'concept_stichting.pdf'},
#          'en': {'<switch>': 'data.alias.key',
#           'spaar-bv': 'concept_en.pdf',
#           'normal-bv': 'concept_en.pdf',
#           'holding': 'concept_en.pdf',
#           'stichting': 'concept_stichting.pdf'}}},
#        'products': {'package': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_stichting'}},
#            {'name': 'Stichting',
#             'count': {'<switch>': 'data.locale', 'nl': 1, 'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_stichtingpakket'}},
#            {'name': 'Contractenpakket voor een stichting', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat'}},
#            {'name': 'Wettelijke bijdrage Kwaliteitsfonds Notariaat',
#             'count': {'<switch>': 'data.locale', 'nl': 1, 'en': 0}}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bijdrage_kwaliteitsfonds_notariaat_en'}},
#            {'name': 'Legal contribution to the Quality Fund for the Dutch Notarial Profession',
#             'count': {'<switch>': 'data.locale', 'nl': 0, 'en': 1}}]}],
#         'addons': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_boekhouding'}},
#            {'name': 'Help mij met mijn boekhouding',
#             'description': 'Voorkomen is beter dan genezen. In samenwerking met <strong>offerte.nl</strong> word je gebeld door boekhouder(s) uit jouw omgeving om een passende <strong>vrijblijvende offerte</strong> te ontvangen. Voorkom boetes en start direct met een strakke administratie!',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_spoedoprichting'}},
#            {'name': 'Spoedoprichting',
#             'description': 'Al meer dan 4200 spoedoprichtingen gedaan. De stichting wordt binnen 24 uur voor je opgericht. Wil je morgen kunnen handelen vanuit de stichting? Je hebt direct een notaris nodig voor een spoedoprichting stichting. Met onze unieke 24-uur service, kunnen wij een stichting binnen 24 uur oprichten en inschrijven bij de Kamer van Koophandel.',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_addon_sneloprichten'}},
#            {'name': 'Snel oprichten',
#             'description': 'Stichting wordt binnen 3 á 4 werkdagen in plaats van onze standaard oprichtingsproces van 7 werkdagen voor je opgericht.',
#             'count': {'<switch>': {'on': {'<ref>': 'data.urgency'},
#               'options': {'firm24_addon_sneloprichten': 1,
#                'firm24_addon_spoedoprichting': 0},
#               'default': 0}}}]}],
#         'extras': [{'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders'}},
#            {'name': 'Extra aandeelhouders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_extra_aandeelhouders_en'}},
#            {'name': 'Extra shareholders', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap'}},
#            {'name': 'Aandeelhouder is vennootschap', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_bestaande_vennootschap_en'}},
#            {'name': 'Shareholder is an existing Legal Entity', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_niet_nl'}},
#            {'name': 'Aandeelhouder spreekt geen Nederlands', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_buitenlandse_vennootschap'}},
#            {'name': 'Aandeelhouder is een buitenlandse vennootschap',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn'}},
#            {'name': 'Aandeelhouder is niet woonachtig in Nederland',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_aandeelhouder_geen_bsn_en'}},
#            {'name': 'Shareholder does not live in the Netherlands',
#             'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_foreign_ah'}},
#            {'name': 'Aandeelhouder woont niet in Nederland', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr'}},
#            {'name': 'Additioneel onderzoek o.g.v. Wwft', 'count': 0}]},
#          {'<merge>': [{'<src>': {'<tpl>': '{{ global.config.legalpayment.url }}/products/firm24_additionele_onderzoek_hr_en'}},
#            {'name': 'Additional research due to Wwft', 'count': 0}]}]},
#        'portal': {'<ref>': 'global.config.legalflow.workflows.general.portal'}}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'fill_document_user_step',
#       'update': {'select': 'private_data.legaldocx_document',
#        'patch': False,
#        'data': None,
#        'jmespath': '{id: id}'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'create_stichting_document_step'},
#    {'definition': 'legaldocx',
#     'title': {'<switch>': 'data.locale',
#      'en': 'Client fills out data',
#      'nl': 'Client vult de gegevens in'},
#     'description': {'<switch>': 'data.locale',
#      'en': 'Client fills out data',
#      'nl': 'Client vult de gegevens in'},
#     'internal_description': {'<switch>': 'data.locale',
#      'en': {'<tpl>': 'Start the incorporation process by entering information about your {{ private_data.incorporation_type }}'},
#      'nl': {'<tpl>': 'Vul gegevens in over de {{ private_data.incorporation_type }} om het oprichtingsproces te starten'}},
#     'actor': 'user',
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'load_data_step',
#       'update': {'select': 'private_data.payment_method',
#        'patch': False,
#        'data': None,
#        'jmespath': 'result.payment_method'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': [{'<tpl>': '/users/{{ actors.user.id }}'}, 'admin'],
#       'key': 'ok'}],
#     'display': True,
#     'expect_only_result': True,
#     'document': {'<ref>': 'private_data.legaldocx_document.id'},
#     'key': 'fill_document_user_step'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.legaldocx.url }}/documents/{{private_data.legaldocx_document.id}}.json'},
#      'method': 'GET',
#      'query': [],
#      'headers': {'Accept': 'application/json'},
#      'auth': None,
#      'data': None,
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'remove_data_values_step',
#       'update': [{'select': 'private_data.meta_data',
#         'patch': False,
#         'data': None,
#         'jmespath': 'values'},
#        {'select': 'products',
#         'patch': False,
#         'data': None,
#         'jmespath': 'values.products'},
#        {'select': 'data.legaldocx_document_id',
#         'patch': True,
#         'data': None,
#         'jmespath': 'id'},
#        {'select': 'data.lily',
#         'patch': True,
#         'data': None,
#         'jmespath': 'values.lily'}],
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'load_data_step'},
#    {'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'values': None}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'store_initial_organization',
#       'update': {'select': 'data',
#        'patch': True,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
# ...
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'done'},
#    {'definition': 'form',
#     'title': 'Selecteer de notaris',
#     'description': 'Selecteer notaris die de procedure gaat uitvoeren',
#     'internal_description': 'Selecteer notaris die de procedure gaat uitvoeren',
#     'actor': 'primary',
#     'responses': [{'title': None,
#       'label': 'Selecteer notaris',
#       'feedback': None,
#       'transition': 'remove_previous_notary_relationship',
#       'update': [{'select': 'actors',
#         'patch': True,
#         'data': None,
#         'jmespath': '{notary: {organization: organization}}'},
#        {'select': 'private_data.transition.change_notary',
#         'patch': False,
#         'data': {'<ref>': 'previous_action'},
#         'jmespath': None}],
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'}],
#     'display': True,
#     'expect_only_result': False,
#     'form': {'id': 'bv_oprichten_notaris', 'label': 'Selecteer notaris'},
#     'key': 'select_notary'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ affiliate_organization_id }}/relations/{{ client_organization_id }}'},
#      'method': 'DELETE',
#      'query': {'relationship': 'client'},
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': None,
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'remove_previous_client_relationship',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'remove_previous_client_relationship',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'remove_previous_notary_relationship'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ client_organization_id }}/relations/{{ affiliate_organization_id }}'},
#      'method': 'DELETE',
#      'query': {'relationship': 'affiliate'},
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': None,
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'reload_notary_information',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'reload_notary_information',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'remove_previous_client_relationship'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ actors.notary.organization.id }}'},
#      'method': 'GET',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': None,
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_permission_template_workaround',
#       'update': {'select': 'info.notary',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_permission_template_workaround',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'reload_notary_information'},
#    {'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'affiliate_organization_id': {'<ref>': 'actors.notary.organization.id'},
#       'client_organization_id': {'<ref>': 'private_data.initial_organization.id'}}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_store_template_enriched_affiliate_permissions',
#       'update': {'select': '$', 'patch': True, 'data': None, 'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'notary_select_permission_template_workaround'},
#    {'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'<tpl>': {'/organizations/{{ affiliate_organization_id }}?relation={{ client_organization_id }}': ['read',
#         'write',
#         'delete']}}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_store_template_enriched_client_permissions',
#       'update': {'select': 'private_data.affiliate_permissions',
#        'patch': True,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'notary_select_store_template_enriched_affiliate_permissions'},
#    {'trigger': {'type': 'nop',
#      'response': 'ok',
#      'simulate_response': None,
#      'data': {'<tpl>': {'/organizations/{{ client_organization_id }}?relation={{ affiliate_organization_id }}': ['read',
#         'write',
#         'delete']}}},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_check_is_notary_affiliate_of_user_step',
#       'update': {'select': 'private_data.client_permissions',
#        'patch': True,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'notary_select_store_template_enriched_client_permissions'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ client_organization_id }}/relations/{{ affiliate_organization_id }}'},
#      'method': 'GET',
#      'query': {'relationship': 'affiliate'},
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': [],
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_create_notary_user_relationship',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 404},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'select_notary_create_notary_user_permissions',
#       'update': {'select': 'private_data.notary_permissions',
#        'patch': False,
#        'data': None,
#        'jmespath': '{id: id}'},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'notary_select_check_is_notary_affiliate_of_user_step'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ client_organization_id }}'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'permissions': {'<ref>': 'private_data.affiliate_permissions'}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_create_notary_user_relationship',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'select_notary_create_notary_user_permissions'},
#    {'trigger': {'type': 'http',
#      'url': {},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json', 'X-Session': False},
#      'auth': None,
#      'data': None,
#      'file': None,
#      'requests': {'<ref>': '@.requests'},
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'notary_select_create_notary_user_permissions',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'requests': [{'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ client_organization_id }}/relations'},
#       'data': {'id': {'<ref>': 'affiliate_organization_id'},
#        'direction': 'parent',
#        'relationship': 'affiliate'}},
#      {'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ affiliate_organization_id }}/relations'},
#       'data': {'id': {'<ref>': 'client_organization_id'},
#        'direction': 'child',
#        'relationship': 'client'}}],
#     'key': 'notary_select_create_notary_user_relationship'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.iam.url }}/organizations/{{ client_organization_id }}'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json'},
#      'auth': None,
#      'data': {'permissions': {'<ref>': 'private_data.affiliate_permissions'}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': 'update_dossier_permissions',
#       'update': None,
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'notary_select_create_notary_user_permissions'},
#    {'trigger': {'type': 'http',
#      'url': {'<tpl>': '{{ global.config.dms.url }}/dossiers/{{ private_data.incorporation_dossier.id }}'},
#      'method': 'POST',
#      'query': [],
#      'headers': {'Content-Type': 'application/json', 'X-Session': False},
#      'auth': None,
#      'data': {'permissions': {'<ref>': 'private_data.affiliate_permissions'}},
#      'file': None,
#      'requests': None,
#      'delayed': None},
#     'responses': [{'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': {'<ref>': 'private_data.transition.change_notary'},
#       'update': {'select': 'private_data.dossier',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'ok'},
#      {'title': None,
#       'label': None,
#       'feedback': None,
#       'transition': ':failed',
#       'update': {'select': 'error',
#        'patch': False,
#        'data': None,
#        'jmespath': None},
#       'require_result': None,
#       'require_confirmation': None,
#       'permissions': None,
#       'key': 'error'}],
#     'display': False,
#     'expect_only_result': False,
#     'key': 'update_dossier_permissions'}],
#   'allow_actions': None,
#   'assets': {},
#   'categories': [],
#   'start': 'initialize_process',
#   'published': False,
#   'personal_organization': True,
#   'notify_assets': True,
#   'notify_comments': {'recipients': ['notary', 'primary'],
#    'schedule_delay': '+1 minute',
#    'template': 'process_comments_notifications'},
#   'legalform': None,
#   'contract': {'template': None, 'paragraph': None},
#   'version': '0438b2031d65a5f5bda75046816c9daab8c5a8a9',
#   'permissions': {'*': ['read'], 'admin': ['read', 'write', 'delete']},
#   'debug': False,
#   'locked': False,
#   'sync': {'update': None},
#   'last_modified': datetime.datetime(2020, 1, 2, 11, 40, 16),
#   '_id': 'start-incorporation-firm24-funnel'},
#  'actors': [{'title': 'Cliënt',
#    'requirement': None,
#    'id': '5d80c418b7ed4bc51b8b4567',
#    'organization': '5d80c418b7ed4bc51b8b4568',
#    'absent': False,
#    'key': 'user'},
#   {'title': 'Notaris',
#    'requirement': None,
#    'id': None,
#    'organization': None,
#    'absent': False,
#    'key': 'notary'},
#   {'title': 'Firm24',
#    'requirement': None,
#    'id': None,
#    'organization': None,
#    'name': None,
#    'absent': False,
#    'key': 'primary'}],
#  'previous': [],
#  'current': {'key': 'fill_document_user_step',
#   'activation_date': datetime.datetime(2020, 1, 3, 12, 53, 58),
#   'due_date': None,
#   'title': 'Client vult de gegevens in',
#   'allow_actions': None,
#   'chained_hash': None,
#   'actor': {'key': 'user',
#    'id': '5d80c418b7ed4bc51b8b4567',
#    'organization': '5d80c418b7ed4bc51b8b4568',
#    'organization_name': 'Jan George',
#    'email': 'info@nrgsolutions.nl',
#    'name': 'Jan George'}},
#  'private_data': {'incorporation_type': 'Holding',
#   'legaldocx_document': {'id': 'okk48c0ks880swkswosw4wgcowg4wosg0gsc0oo00kogsgws8sogo840wsk40cw0'}},
#  'creation': datetime.datetime(2020, 1, 3, 12, 53, 56),
#  'comments': [],
#  'portal': 'firm24'}

# %%
cursor = legalthings_db['processes_18'].find({"_id": ObjectId("5e0f7522643b53c4248b4568")})

# %%
cursor[0]['private_data']['meta_data']['ah']

# %% [markdown]
# #### Check if column exists

# %%
cursor = legalthings_db['processes_18'].find({"private_data.meta_data.ah": {"$exists": True}})

# %%
cursor.count()

# %% [markdown]
# #### Normalize on nested JSON

# %%
cursor = legalthings_db['processes_18'].find({"private_data.meta_data.ah": {"$exists": True}})

# %%
df = json_normalize(cursor, [['private_data', 'meta_data', 'ah']], ['_id', 'name'])

# %%
len(df['_id'].unique()), df.shape

# %% [markdown]
# #### Find Documents using Logical Conditions
# * https://specify.io/how-tos/find-documents-in-mongodb-using-the-mongo-shell

# %%
cursor = legalthings_db['processes_18'].find({
    "$and": [
        {"current.title": "Cliënt rondt de betaling af"},
        {"private_data.meta_data.ah": {"$exists": True}}
    ]
})

# %%
cursor.count()
# Out:
# /mnt/c/projects/riskmodel/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 2

# %%
cursor = legalthings_db['processes_18'].find({
    "$or": [
        {"_id": ObjectId("5e0f3964526253513f8b4567")},
        {"_id": ObjectId("5e0f39b97873f1bf54cb660b")}
  ]
})

# %%
cursor.count()
# Out:
# /mnt/c/projects/riskmodel/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 2

# %%
cursor = legalthings_db['processes_18'].find({
    "$and": [
        {
            "$or": [{"_id": ObjectId("5e0f3964526253513f8b4567")},
                    {"_id": ObjectId("5e0f396fda6fdf1e5860a9e0")}]
        },
        {
            "$or": [{"name": "Jan George | n.t.b"},
                    {"name": "Michael Nieveld | n.t.b"}]
        }
    ]
})

# %%
cursor.count()
# Out:
# /mnt/c/projects/riskmodel/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use Collection.count_documents instead.
#   """Entry point for launching an IPython kernel.
# 2

# %% [markdown]
# ### Make dataframe of collection

# %%
df = DataFrame(list(legalthings_db.incorporation_processes.find({})))

# %%
df.shape

# %%
df.head(n=2)

# %% [markdown]
# #### Normalize JSON

# %% [markdown]
# However the subdocuments will just appear as JSON inside the subdocument cell. If you want to flatten objects so that subdocument properties are shown as individual cells you can use json_normalize without any parameters.

# %%
datapoints = list(legalthings_db.incorporation_processes.find({}))

# %%
df = json_normalize(datapoints)

# %% [markdown]
# ### First exploration of the data
# * Important note: collection is still small subset of the total collection, otherwise we run into memory problems
# * In a later stadium, most important data is extracted the total collection

# %%
df.shape, len(df['_id'].unique()), len(df['name'].unique()), df['title'].unique(), df['current.title'].unique()

# %% [markdown]
# Drop columns with all missings

# %%
df = df.dropna(axis=1, how='all')

# %%
df.shape

# %% [markdown]
# Get duplicate company names

# %%
df[df['name'].duplicated(keep=False)].sort_values('name').head()

# %% [markdown]
# Get companies with status 'Cliënt rond de betaling af' --> probably shows whole funnel

# %%
companies_funnel_all = (
    df[df['current.title'].isin(['Cliënt rond de betaling af', 'Cliënt rondt de betaling af'])]
    ['name']
    .unique()
)

len(companies_funnel_all)

# %%
df[df['name'] == companies_funnel_all[0]].dropna(axis=1, how='all')

# %% [markdown]
# #### Still some nested data --> show 1 collection to explore JSON structure

# %%
legalthings_db.incorporation_processes.find_one()

# %% [markdown]
# Example unnest 'scenario.alias' and add some extra information
# * https://stackoverflow.com/questions/47242845/pandas-io-json-json-normalize-with-very-nested-json

# %%
json_normalize(datapoints, [['scenario', 'alias']], ['_id', 'title','name']).head()

# %% [markdown]
# #### Unnest company with probably a lot of information within nested fields

# %%
df[df['name'] == companies_funnel_all[0]].dropna(axis=1, how='all')

# %%
filter_query = { "name": "MEA" }

datapoint = list(legalthings_db.incorporation_processes.find(filter_query))

# %% [markdown]
# #### private_data.meta_data.kvk.type_toelichting

# %%
df[df['name'] == companies_funnel_all[0]].dropna(axis=1, how='all')['private_data.meta_data.kvk.type_toelichting']

# %% [markdown]
# #### private_data.meta_data.ah --> Nice, NAW information

# %%
json_normalize(datapoint, [['private_data', 'meta_data', 'ah']], ['_id', 'title','name'])

# %% [markdown]
# #### private_data.assets.invoice.versions

# %%
json_normalize(datapoint, [['private_data', 'assets', 'invoice', 'versions']], ['_id', 'title','name'])

# %% [markdown]
# #### private_data.assets.invoice.created.user.employment

# %%
json_normalize(datapoint, [['private_data', 'assets', 'invoice', 'created', 'user', 'employment']])

# %% [markdown]
# #### private_data.assets.invoice.last_updated.user.employment

# %%
json_normalize(datapoint, [['private_data', 'assets', 'invoice', 'last_updated', 'user', 'employment']])

# %% [markdown]
# #### private_data.products

# %%
json_normalize(datapoint, [['private_data', 'products']])

# %% [markdown]
# #### private_data.payment.products

# %%
json_normalize(datapoint, [['private_data', 'payment', 'products']])

# %% [markdown]
# #### private_data.payment.user.authz_groups

# %%
json_normalize(datapoint, [['private_data', 'payment', 'user', 'authz_groups']])

# %% [markdown]
# #### private_data.payment.user.employment

# %%
json_normalize(datapoint, [['private_data', 'payment', 'user', 'employment']])
